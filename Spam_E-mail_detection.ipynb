# %% [raw]
# ⭐Importing Libraries

# %%
import numpy as np
import pandas as pd
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel("Spam Email Detection.xlsx")

# %%
print(df)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will �_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.drop(df.columns[2:6], axis=1, inplace=True)
print(df)
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will �_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.loc[df['v1']=='spam','v1',]=0
df.loc[df['v1']=='ham','v1',]=1

# %%
category=df['v1']
message=df['v2']

# %%
print(category)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: v1, Length: 5572, dtype: object

# %%
print(message)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will �_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: v2, Length: 5572, dtype: object

# %%
category_train,category_test,message_train,message_test=train_test_split(category,message,test_size=0.2,random_state=3)
#from this line divided dataset into test,train dataset with 80% training , 20% testing

# %%
print(category.shape)
print(category_train.shape)
print(category_test.shape)
print(message.shape)
print(message_train.shape)
print(message_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)
# (5572,)
# (4457,)
# (1115,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Convert integer data to strings
message_train = [str(msg) for msg in message_train]
# Initialize the TfidfVectorizer with appropriate parameters
feature_extraction = TfidfVectorizer(min_df=1, stop_words='english', lowercase=True)

# Transform the training messages into feature vectors
message_train_features = feature_extraction.fit_transform(message_train)

# Transform the test messages into feature vectors using the same vocabulary as the training data
message_test_features = feature_extraction.transform(message_test)

# Convert category_train and category_test to integers if they are not already
category_train = category_train.astype(int)
category_test = category_test.astype(int)

# %%
print(message_train_features)
# Out:
#   (0, 742)	0.32207229533730536
#   (0, 3962)	0.2411608243124387
#   (0, 4279)	0.3893042361045832
#   (0, 6580)	0.20305518394534605
#   (0, 3375)	0.32207229533730536
#   (0, 2116)	0.38519642807943744
#   (0, 3126)	0.4403035234544808
#   (0, 3251)	0.258880502955985
#   (0, 3369)	0.21816477736422235
#   (0, 4497)	0.2910887633154199
#   (1, 4045)	0.380431198316959
#   (1, 6850)	0.4306015894277422
#   (1, 6397)	0.4769136859540388
#   (1, 6422)	0.5652509076654626
#   (1, 7420)	0.35056971070320353
#   (2, 934)	0.4917598465723273
#   (2, 2103)	0.42972812260098503
#   (2, 3899)	0.40088501350982736
#   (2, 2220)	0.413484525934624
#   (2, 5806)	0.4917598465723273
#   (3, 6121)	0.4903863168693604
#   (3, 1595)	0.5927091854194291
#   (3, 1838)	0.3708680641487708
#   (3, 7430)	0.5202633571003087
#   (4, 2523)	0.7419319091456392
#   :	:
#   (4452, 2116)	0.3092200696489299
#   (4453, 1000)	0.6760129013031282
#   (4453, 7250)	0.5787739591782677
#   (4453, 1758)	0.45610005640082985
# ...

# %%
model=LogisticRegression()

# %%
model.fit(message_train_features, category_train)
# Out:
# LogisticRegression()

# %%
prediction_on_training_data=model.predict(message_train_features)
accuracy_on_training_data=accuracy_score(category_train,prediction_on_training_data)
print("accuracy on training data: " , accuracy_on_training_data)
# Out:
# accuracy on training data:  0.9661207089970832

# %%
prediction_on_testing_data=model.predict(message_test_features)
accuracy_on_testing_data=accuracy_score(category_test,prediction_on_testing_data)
print("accuracy on testing data: " , accuracy_on_testing_data)
# Out:
# accuracy on testing data:  0.9623318385650225

# %%
input_your_mail=["07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder. Please call now 08000930705 for delivery tomorrow"]
input_data_features=feature_extraction.transform(input_your_mail)
prediction=model.predict(input_data_features)
print(prediction)

if(prediction[0]==1):
    print("not a spam mail")
else:
    print("is a spam mail")
# Out:
# [0]
# is a spam mail

# %%
# using random forest algorithm we get more accuarcy
from sklearn.ensemble import RandomForestClassifier

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the Random Forest classifier
rf_classifier.fit(message_train_features, category_train)

# Predict on the test data
category_test_predicted = rf_classifier.predict(message_test_features)
# Out:
# Accuracy: 0.9766816143497757

# %%
# Train the Random Forest classifier
model_2=rf_classifier
model_2.fit(message_train_features, category_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
accuracy = accuracy_score(category_test, category_test_predicted)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9766816143497757

# %%
input_your_mail=["Hello Students of IIIT DM ,We would like to congratulate you on getting shortlisted for the Internship program. ,Unlock Exclusive Opportunities with our 2-Month Training + Internship Program by MICROSOFT! Limited slots available. ,Ready to enhance your skills and collaborate with industry giants? Seize the chance to join our dynamic program designed by MICROSOFT, providing an unparalleled learning experience and hands-on internship.,Students Kindly Go Through All The Information Which Is Mentioned In the Description Of the  Google Form, Before Filling The Google Form;Google Form:= https://forms.gle/f2tamyxQf83d4xTn8 ,Program Highlights:Upon program completion, participants will receive: "]

input_data_features=feature_extraction.transform(input_your_mail)
prediction=rf_classifier.predict(input_data_features)
print(prediction)

if(prediction[0]==1):
    print("not a spam mail")
else:
    print("is a spam mail")
# Out:
# [1]
# not a spam mail
